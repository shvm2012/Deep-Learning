# %% [markdown]
# ### Bengali sentences > code-mixing > Romanization

# %% [markdown]
# #### useful imports

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np, pandas as pd

# %%
import sys
# !{sys.executable} -m pip install googletrans
# Out:
# Requirement already satisfied: googletrans in /usr/local/lib/python3.6/dist-packages (2.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from googletrans) (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->googletrans) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->googletrans) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->googletrans) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->googletrans) (3.0.4)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk import pos_tag
from nltk import word_tokenize
from datetime import datetime
import unicodedata
import random
import time

from googletrans import Translator
translator = Translator()

# %%
def strip_accents(text):
    return ''.join(char for char in unicodedata.normalize('NFKD', text) if unicodedata.category(char) != 'Mn')

# %% [markdown]
# #### data loading

# %%
#### loading POS tagged bangla sentences

temp = []
with open("bengali_pos_tagged_sents.txt","r",encoding="utf-8") as file:
    for line in file:
        temp.append(line.replace("\n","").split(" "))
        
tagged_tokenize_sentence = []

for i in range(len(temp)):
    sent = []
    for word_pos in temp[i]:
        tup = word_pos.split("|")
        sent.append(tup)
    tagged_tokenize_sentence.append(sent)

# %%
temp[0]
# Out:
# ['আশা|NN',
#  'করি|VF',
#  'আপনারা|NN',
#  'এখানে|NST',
#  'এসে|VNF',
#  'খুব|INTF',
#  'মজা|NN',
#  'করেছেন|VF',
#  '।|PUNC']

# %%
bn_pos_sents = (np.array(tagged_tokenize_sentence)).copy()
bn_pos_sents[0]
# Out:
# [['আশা', 'NN'],
#  ['করি', 'VF'],
#  ['আপনারা', 'NN'],
#  ['এখানে', 'NST'],
#  ['এসে', 'VNF'],
#  ['খুব', 'INTF'],
#  ['মজা', 'NN'],
#  ['করেছেন', 'VF'],
#  ['।', 'PUNC']]

# %%
### loading actual bengali and english sentences

def load_data(file):
    sentences = []
    with open(file, 'r', encoding="utf-8") as f:
        for line in f:
            sentences.append(line.replace("-","").replace("...","").replace("..","").strip())
    return sentences

en_sents = load_data("english_sents.txt")
bn_sents = load_data("bengali_sents.txt")

print(bn_sents[0])
print(en_sents[0])
# Out:
# আশা করি আপনারা এখানে এসে খুব মজা করেছেন ।
# I hope you have had a lot of fun here.

# %% [markdown]
# #### code_mixing function (replaces certain bangla words with their correspomding english words)

# %%
def code_mix(exp_sent):
  
    """0. Rules for CCS """

    rest_NN  = ["CCS"] # ,"QTC","QTO","QTF"]
    for w_pos in exp_sent:
        if w_pos[1] in rest_NN:
            temp_eng = word_tokenize(translator.translate(w_pos[0],src = "bn",dest = "en").text)
            if len(temp_eng) == 1:
                w_pos[0] = temp_eng[0]
    
    """ 1. Rules for JJ"""
    
    # JJ at SOS
    if len(exp_sent)>1:
        if exp_sent[0][1] == "JJ" and exp_sent[1][1] != "JJ":
            temp_words = exp_sent[0][0]+" "+exp_sent[1][0]
            en_word_pos = nltk.pos_tag(word_tokenize(translator.translate(temp_words,src = "bn",dest = "en").text))

            nltk_pos  = [i[1] for i in en_word_pos]

            try:
                word_index = nltk_pos.index("JJ")
            except:
                word_index = "NULL"

            if word_index!="NULL":
                exp_sent[0][0] = en_word_pos[word_index][0]

                
    # JJ at End of the sentence < EOS >
    if len(exp_sent)>1:
        if exp_sent[-1][1] == "JJ" and exp_sent[-2][1] != "JJ":
            temp_words =  exp_sent[-2][0]+ exp_sent[-1][0]
            en_word_pos = nltk.pos_tag(word_tokenize(translator.translate(temp_words,src = "bn",dest = "en").text))

            nltk_pos  = [i[1] for i in en_word_pos]

            try:
                word_index = nltk_pos.index("JJ")
            except:
                word_index = "NULL"

            if word_index!="NULL":
                exp_sent[-1][0] = en_word_pos[word_index][0]


    # JJ at mid-sentence < MID >
    """ obtaining indices of the JJ tagged words which are to replaced with their english words"""

    pos_in_sent = [i[1] for i in exp_sent]
    JJ_mid_indices = [i for i,x in enumerate(pos_in_sent) if x == 'JJ']
    
    if len(pos_in_sent)-1 in JJ_mid_indices:
        JJ_mid_indices.remove(len(pos_in_sent)-1)
    
    if len(JJ_mid_indices)>1:
        if np.logical_and(JJ_mid_indices[0]==0,JJ_mid_indices[1]==1):
            JJ_mid_indices.remove(1)
    
    fin_JJ_mid_indices = [-2]
    for index in JJ_mid_indices:
        if index-fin_JJ_mid_indices[-1]>2:
            fin_JJ_mid_indices.append(index)
    fin_JJ_mid_indices.remove(-2)   

    
    def replace_ADJ(x): ## helper function to replace all nltk JJ POS tags to single noun category "JJ"
        if x in ["JJ"]:
            x = "JJ"
        return x
      

    for index in fin_JJ_mid_indices:

        proceed = []
        try:
            eval(exp_sent[index][0])
            proceed.append("no")
        except:
            proceed.append("yes")

        if proceed[0]=="yes":
            temp_words = exp_sent[index-1][0] +" "+ exp_sent[index][0] #+ " " + exp_sent[index+1][0]
            en_word_pos = nltk.pos_tag(word_tokenize((translator.translate(temp_words,src = "bn",dest = "en").text).lower()))

            nltk_pos  = [i[1] for i in en_word_pos]

            for i in range(len(nltk_pos)):
                nltk_pos[i] = replace_ADJ(nltk_pos[i])

            if np.prod(np.array(nltk_pos)=="JJ")==1:
                word_index = len(nltk_pos)-1

            else:
                try:
                    word_index = nltk_pos.index("JJ") 
                except:
                    word_index = "NULL"

            if word_index!="NULL":
                exp_sent[index][0] = en_word_pos[word_index][0]  

    
    """ 2. Rules for NN """
    # """ NN at start of the sentence < SOS > """
    
        
    def replace_noun(x): ## helper function to replace all nltk noun POS tags to single noun category "NN"
        if x in ["NNP","NNS","NNPS"]:
            x = "NN"
        return x
    
    if len(exp_sent)>1:
        if exp_sent[0][1] == "NN" and exp_sent[1][1] != "NN":
            temp_words = exp_sent[0][0]+" "+exp_sent[1][0]
            en_word_pos = nltk.pos_tag(word_tokenize(translator.translate(temp_words,src = "bn",dest = "en").text))

            nltk_pos  = [i[1] for i in en_word_pos]
            
            for i in range(len(nltk_pos)):
                nltk_pos[i] = replace_noun(nltk_pos[i])

            try:
                word_index = nltk_pos.index("NN")
            except:
                word_index = "NULL"

            if word_index!="NULL":
                exp_sent[0][0] = en_word_pos[word_index][0]

                
    # """ NN at End of the sentence < EOS > """
    if len(exp_sent)>1:
      if exp_sent[-1][1] == "NN" and exp_sent[-2][1] != "NN":
          temp_words = exp_sent[-2][0]+ exp_sent[-1][0]
          en_word_pos = nltk.pos_tag(word_tokenize(translator.translate(temp_words,src = "bn",dest = "en").text))

          nltk_pos  = [i[1] for i in en_word_pos]
          for i in range(len(nltk_pos)):
              nltk_pos[i] = replace_noun(nltk_pos[i])

          try:
              word_index = nltk_pos.index("NN")
          except:
              word_index = "NULL"

          if word_index!="NULL":
              exp_sent[-1][0] = en_word_pos[word_index][0]


    """ NN at mid-sentence < MID > """
    """ obtaining indices of the NN tagged words which are to replaced with their english words"""

    pos_in_sent = [i[1] for i in exp_sent]
    NN_mid_indices = [i for i,x in enumerate(pos_in_sent) if x == 'NN']
    
    if len(pos_in_sent)-1 in NN_mid_indices:
        NN_mid_indices.remove(len(pos_in_sent)-1)
    
    if len(NN_mid_indices)>1:
        if np.logical_and(NN_mid_indices[0]==0,NN_mid_indices[1]==1):
            NN_mid_indices.remove(1)
    
    fin_NN_mid_indices = [-2]
    for index in NN_mid_indices:
        if index-fin_NN_mid_indices[-1]>2:
            fin_NN_mid_indices.append(index)
    fin_NN_mid_indices.remove(-2)   

      
    for index in fin_NN_mid_indices:

        proceed = []
        try:
            eval(exp_sent[index][0])
            proceed.append("no")
        except:
            proceed.append("yes")

        if proceed[0]=="yes":
            temp_words = exp_sent[index-1][0] +" "+ exp_sent[index][0] #+ " " + exp_sent[index+1][0]
            en_word_pos = nltk.pos_tag(word_tokenize((translator.translate(temp_words,src = "bn",dest = "en").text).lower()))

            nltk_pos  = [i[1] for i in en_word_pos]

            for i in range(len(nltk_pos)):
                nltk_pos[i] = replace_noun(nltk_pos[i])

            if np.prod(np.array(nltk_pos)=="NN")==1:
                word_index = len(nltk_pos)-1

            else:
                try:
                    word_index = nltk_pos.index("NN")
                except:
                    word_index = "NULL"

            if word_index!="NULL":
                exp_sent[index][0] = en_word_pos[word_index][0]  

  
    cm_sent = ""
    for i in exp_sent:
        cm_sent = cm_sent + " " +i[0]
    
    return cm_sent.strip()

# %% [markdown]
# #### sentence romanization function (romanizes code-mix sentences)

# %%
def roman_cm(cm_sentence):
    try:
        t_raw = translator.translate(cm_sentence,dest = "bn").pronunciation
        roman_cm_sentence = strip_accents(t_raw).replace("'","")
    except:
        roman_cm_sentence = "TRANSLATION ERROR"
    return roman_cm_sentence

# %% [markdown]
# #### data synthesis (generating code-mixed romanized sentences)

# %%
bn_ro_en_sents = []

for i in range(len(bn_sents)):
    cm = code_mix(bn_pos_sents[i])
    ro = roman_cm(cm)
    bn_ro_en_sents.append([bn_sents[i], ro, en_sents[i]])
        
    print(i)
    print("Bangla: ", bn_ro_en_sents[i][0])
    print("Romanized: ", bn_ro_en_sents[i][1])
    print("English: ", bn_ro_en_sents[i][2],"\n\n")
# Out:
# 0
# Bangla:  আশা করি আপনারা এখানে এসে খুব মজা করেছেন ।
# Romanized:  Hope kari apanara ekhane ese khuba maja karechena.
# English:  I hope you have had a lot of fun here.
#
#
# 1
# Bangla:  এর স্ফটিক ;
# Romanized:  Era crystal;
# English:  Its crystals;
#
#
# 2
# Bangla:  আমি আপনাকে সাহায্য করবো ।
# Romanized:  Ami apanake help karabo.
# English:  I will help you
#
#
# 3
# Bangla:  গেট খোলো .
# Romanized:  Geta kholo.
# English:  Open the gate
#
#
# 4
# Bangla:  আমি বিশ্বাস করি এটা আমার জন্য ভালো কিছু এনে দিয়েছে , আর আমি বলবো , ঈশ্বর এর মঙ্গল করুন !
# Romanized:  Ami i kari eta amara janya good kichu ene diyeche, ara ami balabo, god era mangala karuna!
# English:  I believe it has brought something good to me, and I will say, God bless it!
#
#
# 5
# Bangla:  আমরা দ্বিতীয় ধাপ করিনি !
# Romanized:  Amara dbitiya step karini!
# English:  We didn't do the second step!
#
#
# 6
# Bangla:  তোমার মুখটা দেখার মত ।
# Romanized:  Tomara face dekhara mata.
# English:  Your face is like a watch
#
#
# 7
# Bangla:  আমার লোকেরা আমাকে পথ দেখাবে .
# Romanized:  Amara people amake patha dekhabe.
# English:  My people will show me the way
#
#
# 8
# Bangla:  শুধু এখন কিছু করার আছে তাহলো লাইভ কন্ডিশনে অপটিক্স পরীক্ষা করা .
# Romanized:  Sudhu ekhana kichu karara ache tahale laibha kandisane apatiksa test kara.
# English:  All you have to do now is to test the optics in a live condition.
#
#
# 9
# Bangla:  আমাদের থাকার জন্য একটা জায়গা লাগবে .
# Romanized:  Amadera thakara janya ekata place lagabe.
# English:  We need a place to stay.
#
#
# 10
# Bangla:  অন্তিম সময় পর্যন্ত ।
# Romanized:  Last time paryanta.
# English:  Till the end.
#
#
# 11
# Bangla:  তুমি কি কাউকে ভাড়া করেছ আমাকে ট্রায়ালে কি বলতে হবে তা শিখিয়ে দেওয়ার জন্য , ফেলিক্স ?
# Romanized:  Tumi ki kauke someone karecha amake trial ki balate habe ta sikhiye deoyara janya, felix?
# English:  Have you hired someone to teach me what to say at trial, Felix?
#
#
# 12
# Bangla:  বিমানের জিনিসপাতি কি মেকানিক স্কুল থেকে শিখেছ ?
# Romanized:  Bimanera jinisapati ki mekanika school theke sikhecha?
# English:  Did the airplane mechanic learn from the mechanic's school?
#
#
# 13
# Bangla:  সে পুলিশের প্রতি ভয় পুরোপুরি ভয় কাটিয়ে ওঠে
# Romanized:  Se pulisera prati bhaya puropuri fear katiye othe
# English:  He completely overcame his fear of the police
#
#
# 14
# Bangla:  অথবা ঐ ছুরির ব্যাপারটা .
# Romanized:  Athaba ai knife byaparata.
# English:  Or that knife thing.
#
#
# 15
# Bangla:  PTA মিটিংয়ে বন্ধু জমাতে হলে সবার জন্য ঝালমুড়ি নিয়ে আসবেন
# Romanized:  PTA mitinye friends jamate hale everyone janya jhalamuri niye asabena
# English:  If you want to bring a friend to the PTA meeting, you will bring a flush for everyone.
#
#
# 16
# Bangla:  না , না , না , থামো , প্লিজ থামো ।
# Romanized:  Na, na, na, stop, plija thamo.
# English:  No, no, no, stop, please.
#
#
# 17
# Bangla:  মোয়া নদীর পাশে .
# Romanized:  Moya river pase.
# English:  On the Moa River
#
#
# 18
# Bangla:  কোনও ধারনা আছে কিভাবে এটা ঘটলো ?
# Romanized:  Konao ideas ache kibhabe eta ghatalo?
# English:  Have any idea how this happened?
#
#
# 19
# Bangla:  কচু , এখানে কিছুই আর সুরক্ষিত থাকবে না .
# Romanized:  Kacu, ekhane nothing ara suraksita thakabe na.
# English:  Bitch, nothing will be safe here.
#
#
# 20
# Bangla:  দরজা খোল , আমরা মহামান্য রাজার পক্ষ থেকে এসেছি .
# Romanized:  Daraja khola, amara mahamanya majesty paksa theke esechi.
# English:  Open the door, we're on the King's side.
#
#
# 21
# Bangla:  তা সত্ত্বেও তুমি যদি অন্য আরেকটা মিথ্যা বলো .
# Romanized:  Ta sattbeo tumi If anya arekata mithya balo.
# English:  Yet if you tell another lie
#
#
# 22
# Bangla:  এবং তাদের পাহাড়ার মধ্যে রাখুন ।
# Romanized:  Ebam tadera hills madhye rakhuna.
# English:  And put them in the mountains.
#
#
# 23
# Bangla:  এটা কোন ভাল আইডিয়া না ।
# Romanized:  Eta kona bhala aidiya na.
# English:  This is not a good idea.
#
#
# 24
# Bangla:  আপনি যদি করত একটি হত্যা জাদুকরী ,
# Romanized:  Apani If kare ekati murder jadukari,
# English:  If you were a killing witch,
#
#
# 25
# Bangla:  কোথায় গেলো সেই উদ্দাম সাহস ?
# Romanized:  Kothaya gela sei uddama courage?
# English:  Where did the courage to go?
#
#
# 26
# Bangla:  আর এর কারন হলো ওর মা একজন কৃষক ছিলো আপনাদের মতো আর শহর থেকে কাজ করে বাড়ি ফেরার পথে দূর্ঘটনায় মারা যায়
# Romanized:  Ara era karana halo ora mother ekajana krsaka farmer apanadera mato ara city theke kaja kare home pherara pathe accident mara yaya
# English:  And the reason is that his mother was a farmer like you and died in an accident on the way home from work.
#
#
# 27
# Bangla:  আর সেই আইন পারে আপনাদেরকে বিচ্ছেদ করে দিতে .
# Romanized:  Ara sei law pare apanaderake separation kare dite.
# English:  And that law can split you.
#
#
# 28
# Bangla:  দুই , এখানে সবচেয়ে বড় সমস্যা ভাষা ।
# Romanized:  Dui, ekhane sabaceye bara problem bhasa.
# English:  Two, the biggest problem here is the language.
#
#
# 29
# Bangla:  চলবে , চলবে ।
# Romanized:  Calabe, calabe.
# English:  Go on, go on.
#
#
# 30
# Bangla:  আমি তার গড়ে ওঠা মেজোভ ( Mojave ) মরুভূমিতে .
# Romanized:  Ami tara gare otha mejobau (Mojave) desert.
# English:  I grew up in the Mojave Desert.
#
#
# 31
# Bangla:  ওই বোতলটা দিতে পারবে ?
# Romanized:  Oi bottle dite parabe?
# English:  Can you give me that bottle?
#
#
# 32
# Bangla:  আয়োডিন এবং এন্টিহিস্টামিন শেষ ,
# Romanized:  Iodine ebam entihistamina antihistamine,
# English:  End of iodine and antihistamine,
#
#
# 33
# Bangla:  কিছু জিজ্ঞাসা করার থাকলে একে জিজ্ঞাসা করো ।
# Romanized:  Kichu anything karara thakale eke jijnasa karo.
# English:  If you have anything to ask, ask it.
#
#
# 34
# Bangla:  রিভেঞ্জ , ঠিক আছে ?
# Romanized:  Ribhenja, right ache?
# English:  Revenge, okay?
#
#
# 35
# Bangla:  কিভাবে জানো ?
# Romanized:  Kibhabe jano?
# English:  How do you know
#
#
# 36
# Bangla:  কিন্তু আমাদের তো সমাজে মানিয়ে চলার চেষ্টা করা উচিত না
# Romanized:  But amadera to society maniye calara try kara ucita na
# English:  But we should not try to adapt to society
#
#
# 37
# Bangla:  মনে হচ্ছে সন্ধ্যাটা সাফল্যে ভরপুর .
# Romanized:  Mane hacche evening saphalye bharapura.
# English:  Looks like the evening was a success.
#
#
# 38
# Bangla:  ডেভিডের তাকে ঝাঁকানো উচিত , মনিকা কোনদিন জাগবে না ।
# Romanized:  David take dekhano ucita, manika konadina jagabe na.
# English:  David should show her, Monica will never wake up.
#
#
# 39
# Bangla:  ওই , হারামীর বাচ্চা .
# Romanized:  Oi, haramira bitch.
# English:  Uh, bastard baby
#
#
# 40
# Bangla:  কিন্তু টামনাস এর কি হবে ?
# Romanized:  But tamanasa era ki habe?
# English:  But what about Tamanas?
#
#
# 41
# Bangla:  তদন্তকারীরা আমাকে হুকুম দিয়েছে যে আপনাকে এখনি যেন সেখানে নিয়ে যায়
# Romanized:  Tadantakarira amake command diyeche ye apanake ekhani yena sekhane niye yaya
# English:  Investigators ordered me to get you there
#
#
# 42
# Bangla:  আর বিভিন্ন ছুটিছাটাতে .
# Romanized:  Ara different summer.
# English:  And different holidays
#
#
# 43
# Bangla:  তোর এখনও মনে হয় আমি তোকে শুধু এই কারণে রেখেছিলাম , বলদ ?
# Romanized:  Tora ekhanao mane haya ami i sudhu ei reason rekhechilama, ox?
# English:  You still think I left you just for that, bull?
#
#
# 44
# Bangla:  এটা সঠিক লক্ষ্যে যে রাখুন .
# Romanized:  Eta right laksye ye rakhuna.
# English:  Keep that in the right direction.
#
#
# 45
# Bangla:  তুমি কি আমাকে চ্যালেঞ্জ করছো ?
# Romanized:  Tumi ki amake cyalenja karacho?
# English:  Are you challenging me
#
#
# 46
# Bangla:  সে আমার ছেলেকে পাবে না ।
# Romanized:  Se amara cheleke pabe na.
# English:  He won't get my son.
#
#
# 47
# Bangla:  বাবা Drac ঠিক কিভাবে উড়ে আমাকে শেখান চেষ্টা .
# Romanized:  Baba Drac drac kibhabe ure amake sekhana try.
# English:  Dad Drac just tried to teach me how to fly.
#
#
# 48
# Bangla:  তোমার পকেটে ?
# Romanized:  Tomara pocket?
# English:  In your pocket
#
#
# 49
# Bangla:  নিজের দেশের যুদ্ধ নিয়ে ঘাঁটলে যা হয় ।
# Romanized:  Nijera country yuddha niye hamtale ya haya.
# English:  What happens when you walk in the battle of your own country.
#
#
# 50
# Bangla:  সন্মান জানালাম ।
# Romanized:  Sanmana janalama.
# English:  I was honored.
#
#
# 51
# Bangla:  যেগুলো প্যাচিয়েছে আর ঘুরে গিয়েছে !
# Romanized:  Yegulo pathiyechi ara ghure giyeche!
# English:  The ones who sent and turned around!
#
#
# 52
# Bangla:  শোন না .
# Romanized:  Sona na.
# English:  Don't listen
#
#
# 53
# Bangla:  এটা কিছুতেই মানা যায়না ।
# Romanized:  Eta kichutei mana yayana.
# English:  This is not acceptable at all.
#
#
# 54
# Bangla:  তুমি এখন পর্যন্ত তাকে দেখনি না ?
# Romanized:  Tumi ekhana paryanta take dekhani na?
# English:  You haven't seen him yet?
#
#
# 55
# Bangla:  আমি নিজে যেতে পারবো .
# Romanized:  Ami nije yete parabo.
# English:  I can go on my own.
#
#
# 56
# Bangla:  আমার বান দিবে কি দেবে না ?
# Romanized:  Amara sister dibe ki debe na?
# English:  Will you give me a ban?
#
#
# 57
# Bangla:  আমি ভেতরে যাচ্ছি ।
# Romanized:  Ami bhetare yacchi.
# English:  I'm going in.
#
#
# 58
# Bangla:  আর তার সৎবোনেরা ভাবতে লাগলো
# Romanized:  Ara tara half bhabate lagalo
# English:  And her sisters began to think
#
#
# 59
# Bangla:  এখন আর নেই ।
# Romanized:  Ekhana ara nei.
# English:  Not anymore.
#
#
# 60
# Bangla:  আমরা এত দানব কল কিছুই জানি না .
# Romanized:  Amara eta monsters kala kichui jani na.
# English:  We know nothing to call so many monsters.
#
#
# 61
# Bangla:  যেন মনে হচ্ছিল হেনরি তৎপর ছিল
# Romanized:  Yena mane hacchila henry tatpara chila
# English:  It looked like Henry was in a hurry
#
#
# 62
# Bangla:  মাঙ্গামা , একে নিয়ে গিয়ে ঘরে বন্ধ কর !
# Romanized:  Mangama, eke niye giye home bandha kara!
# English:  Mangama, take it and close the room!
#
#
# 63
# Bangla:  আমরা তিনজন ভাগভাগি করে নিতাম
# Romanized:  Amara tinajana share kare nitama
# English:  We were divided into three
#
#
# 64
# Bangla:  আমাদেরকে এমন এক পন্থা বের করতে হবে , যাতে করে তুমি রান্না করতে পার
# Romanized:  Amaderake emana eka approach bera karate habe, So kare tumi ranna karate Karatepara
# English:  We need to find a way that you can cook
#
#
# 65
# Bangla:  সমস্যা কি ?
# Romanized:  Problem ki?
# English:  What is the problem
#
#
# 66
# Bangla:  নিশ্চিত করে বলতে পারছি , একটি উপায়ে পারব ।
# Romanized:  Confirms kare balate parachi, ekati way paraba.
# English:  I can say for sure, in a way.
#
#
# 67
# Bangla:  আর কি চাওয়ার থাকতে পারে আমার ?
# Romanized:  Ara ki caoyara thakate pare i?
# English:  What else can I ask for?
#
#
# 68
# Bangla:  বেতন একটু বেশি দিতে হবে .
# Romanized:  Pay ekatu besi dite habe.
# English:  Pay a little more
#
#
# 69
# Bangla:  এটা জগণ্য খারাপ .
# Romanized:  Eta jaghanya kharapa.
# English:  It's damn bad
#
#
# 70
# Bangla:  শাস্তি .
# Romanized:  TRANSLATION ERROR
# English:  Punishment.
#
#
# 71
# Bangla:  কিন্ত ঐসব মূর্খদের নিশ্চয়ই বুকে কোন মেশিন নিয়ে বেচে থাকতে হয়নি ‎ .
# Romanized:  Kintu saba murkhadera niscayai chest kona mesina niye bemce thakate hayani ‎ .
# English:  But not all fools have survived with a machine in the chest.
#
#
# 72
# Bangla:  তার জন্য আমরা কাকড়াটাকে খাচ্ছি ।
# Romanized:  Tara janya amara kakaratake khacchi.
# English:  We are eating cucumber for that.
#
#
# 73
# Bangla:  আবার শূন্যে এসে ঘোরপ্যাঁচ খাচ্ছি
# Romanized:  Abara sunye ese ghorapyamca khacchi
# English:  I am coming back to zero and eating
#
#
# 74
# Bangla:  ক্লু প্রোগ্রাম বানাতে পারে না ।
# Romanized:  Klu program banate pare na.
# English:  Clue cannot create programs.
#
#
# 75
# Bangla:  কমাণ্ডার ।
# Romanized:  TRANSLATION ERROR
# English:  Commander.
#
#
# 76
# Bangla:  সবকিছু ঝকঝকে তকতকে হওয়া চাই ,
# Romanized:  Sabakichu teeth takatake haoya cai,
# English:  I want everything to be sharp,
#
#
# 77
# Bangla:  আমি জানি না যে , তুমি আমায় কি বলতো বলছো ।
# Romanized:  Ami jani na ye, tumi amaya ki balato balacho.
# English:  I don't know what you're saying to me.
#
#
# 78
# Bangla:  যখন তার সুনয়না চোখের দিকে তাকিয়েছিলাম
# Romanized:  While tara sunayana cokhera dike takiyechilama
# English:  When I looked at his golden eyes
#
#
# 79
# Bangla:  আমি একদম ক্লান্ত .
# Romanized:  Ami ekadama i.
# English:  I'm so tired
#
#
# 80
# Bangla:  অবশ্যই তার ঘরে আছে
# Romanized:  Abasyai tara house ache
# English:  Of course he's in the room
#
#
# 81
# Bangla:  এর পক্ষেবিপক্ষে মিউট্যান্টদের প্রতিক্রিয়া লক্ষ্য করা যাচ্ছে .
# Romanized:  Era favor miutyanta era pratikriya reactions kara yacche.
# English:  The mutant's reaction against it is being noticed.
#
#
# 82
# Bangla:  সে আপনার সাথে মিথ্যা বলেছে .
# Romanized:  Se apanara sathe mithya baleche.
# English:  He lied to you.
#
#
# 83
# Bangla:  তুমি কি তাদের থামাতে পারবে .
# Romanized:  Tumi ki tadera thamate parabe.
# English:  Can you stop them?
#
#
# 84
# Bangla:  আমি ব্যাপারটা বুঝতে পারছি , সোনা ।
# Romanized:  Ami thing bujhate parachi, honey।
# English:  I understand that, gold.
#
#
# 85
# Bangla:  . আমার খুব ভয় হচ্ছিল যে আমার হৃদয় হয়তো আর কখনো উন্মোচিত হবে না
# Romanized:  . Amara khuba bhaya hacchila ye amara heart hayato ara kakhano unmocita habe na
# English:  I was scared that my heart might never be exposed again
#
#
# 86
# Bangla:  বুঝলে কি বললাম ?
# Romanized:  Bujhale ki balalama?
# English:  Understand what I said?
#
#
# 87
# Bangla:  সেই রাতে , ইউই সিউ পার্ককে হত্যাকারী
# Romanized:  Sei night, iu so park hatyakari
# English:  That night, the killer at Your Sew Park
#
#
# 88
# Bangla:  তোমার মৃত স্ত্রী এবং সন্তানের জন্য আমি প্রার্থনা করছি .
# Romanized:  Tomara dead wife ebam santanera janya ami pray karachi.
# English:  I pray for your dead wife and child.
#
#
# 89
# Bangla:  একজন বালক
# Romanized:  Ekajana boy
# English:  A boy
#
#
# 90
# Bangla:  টার্মিনেটর ইতিমধ্যেই চলে এসেছে .
# Romanized:  Tarminetara itimadhye cale eseche.
# English:  The terminator has already arrived.
#
#
# 91
# Bangla:  অামি কাউকে ভালোবাসিনা ।
# Romanized:  Action kauke bhalobasina.
# English:  I don't love anyone
#
#
# 92
# Bangla:  তুমি কি আমার সাথে মজা করছ .
# Romanized:  Tumi ki amara sathe maja karacha.
# English:  Are you kidding me
#
#
# 93
# Bangla:  তুমি এখানে আমার ‎ .
# Romanized:  Tumi ekhane amara ‎ .
# English:  You're here.
#
#
# 94
# Bangla:  হিটলার এই জিনিসের প্রতি পাগল .
# Romanized:  Hitalara ei thing prati pagala.
# English:  Hitler is crazy about these things.
#
#
# 95
# Bangla:  তুমি কি আমার সাথে মজা করছ ?
# Romanized:  Tumi ki amara sathe maja karacha?
# English:  Are you kidding me
#
#
# 96
# Bangla:  তাহলে তোমার বস কেন তাকে ছাড়াতে চায় ?
# Romanized:  Tahale tomara boss kena take charate caya?
# English:  So why does your boss want to leave her?
#
#
# 97
# Bangla:  হ্যানর ‍ ্যাটি , ম্যাম
# Romanized:  Hyanara ‍ yati, Maam
# English:  Hanner's fatty, ma'am
#
#
# 98
# Bangla:  সবাই পথ খুঁজে বের করো !
# Romanized:  Sabai patha khumje bera karo!
# English:  Find the way everyone!
#
#
# 99
# Bangla:  আমারে দেন , আমি খুলতে পারমু ।
# Romanized:  Amara dina, ami khulate parabo.
# English:  Give it to me, I can open it.
#
#
# 100
# Bangla:  যদি আপনি ভাল পিতা হোন তাহলে .
# Romanized:  If apani good father hona tahale.
# English:  If you are a good father
#
#
# 101
# Bangla:  সেই সময়টাতে দুর্ঘটনার আগে তোর চিন্তাচেতনা , কথাবার্তা একদম পানির মত পরিষ্কার ছিল ।
# Romanized:  Sei time durghatanara age tara cinta cetana, speech ekadama panira water pariskara chila.
# English:  At that time, before the accident, your thoughts, conversations were clear as water.

# %%
# with open('result_file_100_sents.txt', 'w',encoding="utf-8") as f:
#     for bn_en_ro in bn_ro_en_sents:
#         f.write(bn_en_ro[0])
#         f.write("\n")
#         f.write(bn_en_ro[1])
#         f.write("\n")
#         f.write(bn_en_ro[2])
        
#         f.write("\n\n\n")

# %%
# with open('en.txt', 'w',encoding="utf-8") as f:
#     for en in en_sents[:len(rom_temp)]:
#         f.write(en)
#         f.write("\n")

# %%
# with open('bn.txt', 'w',encoding="utf-8") as f:
#     for en in bn_sents[:len(rom_temp)]:
#         f.write(en)
#         f.write("\n")

# %%
# with open('ro.txt', 'w',encoding="utf-8") as f:
#     for en in rom_temp[:len(rom_temp)]:
#         f.write(en)
#         f.write("\n")
